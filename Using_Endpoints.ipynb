# %% [markdown]
# <a href="https://colab.research.google.com/github/VictoriaUsman/LLM-Engineering/blob/main/Using_Endpoints.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI
from google.colab import userdata
key = userdata.get('OPENAI_API_KEY')
import requests
import json

# %%
# Get API key from Colab userdata
api_key = userdata.get('OPENAI_API_KEY')

headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

# Define the payload correctly
payload = {
    "model": "gpt-5-nano",
    "messages": [
        {"role": "user", "content": "Tell me a Tagalog joke"}
    ]
}

# Make the POST request
response = requests.post(
    "https://api.openai.com/v1/chat/completions",
    headers=headers,
    json=payload
)

response.json()
# Out:
# {'id': 'chatcmpl-CaxyhuAIuWwzHu7ssuuloP4JAKk5B',
#  'object': 'chat.completion',
#  'created': 1762926399,
#  'model': 'gpt-5-nano-2025-08-07',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
#     'content': 'Bakit hindi matangkad ang kalendaryo? Kasi bawat araw may petsa. \n\nGusto mo pa ng isa pang Tagalog joke?',
#     'refusal': None,
#     'annotations': []},
#    'finish_reason': 'stop'}],
#  'usage': {'prompt_tokens': 12,
#   'completion_tokens': 3563,
#   'total_tokens': 3575,
#   'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#   'completion_tokens_details': {'reasoning_tokens': 3520,
#    'audio_tokens': 0,
#    'accepted_prediction_tokens': 0,
#    'rejected_prediction_tokens': 0}},
#  'service_tier': 'default',
#  'system_fingerprint': None}

# %% [markdown]
# <a href="https://colab.research.google.com/github/VictoriaUsman/LLM-Engineering/blob/main/First_API_OpenAI_Call.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI
from google.colab import userdata
key = userdata.get('OPENAI_API_KEY')

# %%
openai = OpenAI(api_key=userdata.get('OPENAI_API_KEY'))

# %%
message = "Will I be an LLM Engineer?"

# %%
message =[
    {"role":"system","content": "You are someone like Nostradamus"},
    {"role":"user","content": message}
]

# %%
response = openai.chat.completions.create(
    model="gpt-4",
    temperature=0.9,
    messages=message)

# %%
print(response.choices[0].message.content)
# Out:
# As an AI, I lack the ability to foresee your specific future events. My programming enables me to provide information, answer queries, and facilitate learning based on the data I have been given. Your career path will depend on factors such as your work ethic, passion, and dedication to becoming an LLM Engineer. Good luck with your journey!
